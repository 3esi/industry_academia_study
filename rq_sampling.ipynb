# %% [markdown]
# # Sampling of RQs

# %%
from collections import defaultdict
import csv
import pprint
import random
import os

# %%
def parse_papers_csv(csv_file):
    """
    Parses a CSV file containing information about research papers and organizes it into a structured dictionary.

    Args:
        csv_file (str): The path to the CSV file containing the paper data. The CSV file should have the following columns:
            - 'Domain': The domain or category of the paper.
            - 'Paper Name': The title of the paper.
            - 'Authors': A comma-separated list of authors.
            - 'Distinguished': A string indicating whether the paper is distinguished ('True' or 'False').

    Returns:
        defaultdict: A nested dictionary where each domain key maps to a dictionary containing:
            - 'papers': A list of dictionaries, each representing a paper with the following keys:
                - 'name' (str): The title of the paper.
                - 'authors' (str): A comma-separated string of author names.
                - 'distinguished' (bool): A boolean indicating if the paper is distinguished.
                - 'url' (str): A placeholder string ('No URL available') for the paper's URL.
    """
    merged_dict_all = defaultdict(lambda: {'papers': []})

    with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            domain = row['Domain']
            paper_name = row['Paper Name']
            
            authors = [author.strip() for author in row['Authors'].split(',')]
            authors = ', '.join(authors)
            
            distinguished = row['Distinguished'] == 'True'

            paper_entry = {
                'name': paper_name,
                'authors': authors,
                'distinguished': distinguished,
                'url': 'No URL available'
            }

            merged_dict_all[domain]['papers'].append(paper_entry)

    return merged_dict_all

# %%
def print_papers_by_domain(merged_dict_all):
    """
    Prints a list of papers organized by domain in a readable format.

    Args:
        merged_dict_all (dict): A dictionary where each key is a domain, and the value is a dictionary containing:
            - 'papers': A list of dictionaries, each representing a paper with the following keys:
                - 'name' (str): The title of the paper.
                - 'authors' (str): A comma-separated string of author names.
                - 'distinguished' (bool): A boolean indicating if the paper is distinguished.
                - 'url' (str): A placeholder string for the paper's URL.
    """
    # Iterate over each domain in merged_dict_all
    for domain, domain_data in merged_dict_all.items():
        print(f"Domain: {domain}")
        # Iterate over the list of papers in each domain
        for paper in domain_data['papers']:
            print(f"  Paper Name: {paper['name']}")
            #print(f"    Authors: {paper['authors']}")
            print(f"    Distinguished: {paper['distinguished']}")
            #print(f"    URL: {paper['url']}")
        print("\n")  # Print a newline between domains

# %%
csv_file = 'csv_files/papers_by_domain.csv'
merged_dict_all = parse_papers_csv(csv_file)

# %%
print_papers_by_domain(merged_dict_all)
# Out:
# Domain: domain_ai_se
#   Paper Name: One Adapter for All Programming Languages? Adapter Tuning for Multilingual Tasks in Software Engineering
#     Distinguished: False
#   Paper Name: CCRep: Learning Code Change Representations via Pre-Trained Code Model and Query Back
#     Distinguished: False
#   Paper Name: Keeping Pace with Ever-Increasing Data: Towards Continual Learning of Code Intelligence Models
#     Distinguished: False
#   Paper Name: Automating Code-Related Tasks Through Transformers: The Impact of Pre-training
#     Distinguished: False
#   Paper Name: Log Parsing with Prompt-based Few-shot Learning
#     Distinguished: False
#   Paper Name: Retrieval-Based Prompt Selection for Code-Related Few-Shot Learning
#     Distinguished: False
#   Paper Name: An Empirical Study of Pre-Trained Model Reuse in the Hugging Face Deep Learning Model Registry
#     Distinguished: False
#   Paper Name: ContraBERT: Enhancing Code Pre-trained Models via Contrastive Learning
#     Distinguished: False
#   Paper Name: Are Human Rules Necessary? Generating Reusable APIs with CoT Reasoning and In-context Learning
#     Distinguished: False
#   Paper Name: CodeArt: Better Code Models by Attention Regularization When Symbols Are Lacking
#     Distinguished: False
#   Paper Name: Enhancing Code Understanding for Impact Analysis by Combining Transformers and Program Dependence Graphs
#     Distinguished: False
#   Paper Name: Exploring and Unleashing the Power of Large Language Models in Automated Code Translation
#     Distinguished: False
#   Paper Name: Glitch Tokens in Large Language Models: Categorization Taxonomy and Effective Detection
#     Distinguished: False
#   Paper Name: Code-Aware Prompting: A study of Coverage guided Test Generation in Regression Setting using LLM
#     Distinguished: False
#   Paper Name: Improving the Learning of Code Review Successive Tasks with Cross-Task Knowledge Distillation
#     Distinguished: True
#   Paper Name: Learning to Detect and Localize Multilingual Bugs
#     Distinguished: False
#   Paper Name: Mining Action Rules for Defect Reduction Planning
#     Distinguished: False
#   Paper Name: Predicting Failures of Autoscaling Distributed Applications
#     Distinguished: False
#   Paper Name: RavenBuild: Context, Relevance, and Dependency Aware Build Outcome Prediction
#     Distinguished: False
#   Paper Name: B-AIS: An Automated Process for Black-box Evaluation of AI-enabled Software Systems against Domain Semantics
#     Distinguished: False
#   Paper Name: SmOOD: Smoothness-based Out-of-Distribution Detection Approach for Surrogate Neural Networks in Aircraft Design
#     Distinguished: False
#   Paper Name: Unveiling Hidden DNN Defects with Decision-Based Metamorphic Testing
#     Distinguished: False
#   Paper Name: Patching Weak Convolutional Neural Network Models through Modularization and Composition
#     Distinguished: False
#   Paper Name: Safety and Performance, Why not Both? Bi-Objective Optimized Model Compression toward AI Software Deployment
#     Distinguished: False
#   Paper Name: Are Neural Bug Detectors Comparable to Software Developers on Variable Misuse Bugs?
#     Distinguished: False
#   Paper Name: Learning Contract Invariants Using Reinforcement Learning
#     Distinguished: False
#   Paper Name: Compressing Pre-trained Models of Code into 3 MB
#     Distinguished: False
#   Paper Name: A Transferable Time Series Forecasting Service using Deep Transformer model for Online Systems
#     Distinguished: False
#   Paper Name: Robust Learning of Deep Predictive Models from Noisy and Imbalanced Software Engineering Datasets
#     Distinguished: False
#   Paper Name: FedDebug: Systematic Debugging for Federated Learning Applications
#     Distinguished: False
#   Paper Name: Practical and Efficient Model Extraction of Sentiment Analysis APIs
#     Distinguished: False
#   Paper Name: CrossCodeBench: Benchmarking Cross-Task Generalization of Source Code Models
#     Distinguished: False
#   Paper Name: Reusing Deep Neural Network Models through Model Re-engineering
#     Distinguished: False
#   Paper Name: PyEvolve: Automating Frequent Code Changes in Python ML Systems
#     Distinguished: False
#   Paper Name: DeepArc: Modularizing Neural Networks for the Model Maintenance
#     Distinguished: False
#   Paper Name: Decomposing a Recurrent Neural Network into Modules for Enabling Reusability and Replacement
#     Distinguished: False
#   Paper Name: Towards Understanding Fairness and its Composition in Ensemble Machine Learning
#     Distinguished: False
#   Paper Name: Fairify: Fairness Verification of Neural Networks
#     Distinguished: False
#   Paper Name: Leveraging Feature Bias for Scalable Misprediction Explanation of Machine Learning Models
#     Distinguished: False
#   Paper Name: Information-Theoretic Testing and Debugging of Fairness Defects in Deep Neural Networks
#     Distinguished: False
#   Paper Name: Harnessing Neuron Stability to Improve DNN Verification
#     Distinguished: False
#   Paper Name: MirrorFair: Fixing Fairness Bugs in Machine Learning Software via Counterfactual Predictions
#     Distinguished: False
#   Paper Name: Natural Is The Best: Model-Agnostic Code Simplification for Pre-trained Large Language Models
#     Distinguished: False
#   Paper Name: On Reducing Undesirable Behavior in Deep-Reinforcement-Learning-Based Software
#     Distinguished: False
#   Paper Name: A Light Bug Triage Framework for Applying Large Pre-trained Language Model
#     Distinguished: False
#   Paper Name: CARGO: AI-Guided Dependency Analysis for Migrating Monolithic Applications to Microservices Architecture
#     Distinguished: True
#   Paper Name: PRCBERT: Prompt Learning for Requirement Classification using BERT-based Pretrained Language Models
#     Distinguished: False
#   Paper Name: DeepPerform: An Efficient Approach for Performance Testing of Resource-Constrained Neural Networks
#     Distinguished: False
#   Paper Name: Boosting the Revealing of Detected Violations in Deep Learning Testing: A Diversity-Guided Method
#     Distinguished: True
#   Paper Name: Towards Understanding the Faults of JavaScript-Based Deep Learning Systems
#     Distinguished: False
#   Paper Name: Toward Improving the Robustness of Deep Learning Models via Model Transformation
#     Distinguished: False
#   Paper Name: Autonomy Is An Acquired Taste: Exploring Developer Preferences for GitHub Bots
#     Distinguished: False
#   Paper Name: Flexible and Optimal Dependency Management via Max-SMT
#     Distinguished: False
#   Paper Name: ChatGPT Incorrectness Detection in Software Reviews
#     Distinguished: False
#   Paper Name: ChatGPT-Resistant Screening Instrument for Identifying Non-Programmers
#     Distinguished: False
#   Paper Name: Development in times of hype: How freelancers explore Generative AI?
#     Distinguished: False
#   Paper Name: How Far Are We? The Triumphs and Trials of Generative AI in Learning Software Engineering
#     Distinguished: False
#   Paper Name: Uncovering the Causes of Emotions in Software Developer Communication Using Zero-shot LLMs
#     Distinguished: False
#   Paper Name: EGFE: End-to-end Grouping of Fragmented Elements in UI Designs with Multimodal Learning
#     Distinguished: False
#   Paper Name: A Comprehensive Study of Learning-based Android Malware Detectors under Challenging Environments
#     Distinguished: False
#   Paper Name: Toward Automatically Completing GitHub Workflows
#     Distinguished: False
#   Paper Name: UniLog: Automatic Logging via LLM and In-Context Learning
#     Distinguished: False
#   Paper Name: Large Language Models for Test-Free Fault Localization
#     Distinguished: False
#   Paper Name: Dataflow Analysis-Inspired Deep Learning for Efficient Vulnerability Detection
#     Distinguished: False
#   Paper Name: Xpert: Empowering Incident Management with Query Recommendations via Large Language Models
#     Distinguished: False
#   Paper Name: Tensor-Aware Energy Accounting
#     Distinguished: False
#   Paper Name: Programming Assistant for Exception Handling with CodeBERT
#     Distinguished: False
#   Paper Name: An Empirical Study on Noisy Label Learning for Program Understanding
#     Distinguished: False
#   Paper Name: An Empirical Study on Low GPU Utilization of Deep Learning Jobs
#     Distinguished: False
#   Paper Name: Using an LLM to Help With Code Understanding
#     Distinguished: False
#   Paper Name: Enhancing Exploratory Testing by Large Language Model and Knowledge Graph
#     Distinguished: False
#   Paper Name: LLMParser: An Exploratory Study on Using Large Language Models for Log Parsing
#     Distinguished: False
#   Paper Name: Make LLM a Testing Expert: Bringing Human-like Interaction to Mobile GUI Testing via Functionality-aware Decisions
#     Distinguished: False
#   Paper Name: Predicting Performance and Accuracy of Mixed-Precision Programs for Precision Tuning
#     Distinguished: False
#   Paper Name: Design by Contract for Deep Learning APIs
#     Distinguished: False
#   Paper Name: Testing Coreference Resolution Systems without Labeled Test Sets
#     Distinguished: False
#   Paper Name: Neural-Based Test Oracle Generation: A Large-scale Evaluation and Lessons Learned
#     Distinguished: False
#   Paper Name: Revisiting Neural Program Smoothing for Fuzzing
#     Distinguished: False
#   Paper Name: [Remote] Compatibility Issues in Deep Learning Systems: Problems and Opportunities
#     Distinguished: False
#   Paper Name: [Remote] An Extensive Study on Adversarial Attack against Pre-trained Models of Code
#     Distinguished: False
#   Paper Name: Can Machine Learning Pipelines Be Better Configured?
#     Distinguished: True
#   Paper Name: Fix Fairness, Don’t Ruin Accuracy: Performance Aware Fairness Repair using AutoML
#     Distinguished: False
#   Paper Name: BiasAsker: Measuring the Bias in Conversational AI System
#     Distinguished: False
#   Paper Name: Pitfalls in Experiments with DNN4SE: An Analysis of the State of the Practice
#     Distinguished: False
#   Paper Name: DecompoVision: Reliability Analysis of Machine Vision Components Through Decomposition and Reuse
#     Distinguished: False
#   Paper Name: Benchmarking Robustness of AI-enabled Multi-sensor Fusion Systems: Challenges and Opportunities
#     Distinguished: True
#   Paper Name: Automated Testing and Improvement of Named Entity Recognition Systems
#     Distinguished: False
#   Paper Name: Deep Learning Based Feature Envy Detection Boosted by Real-World Examples
#     Distinguished: False
#   Paper Name: [Remote] The EarlyBIRD Catches the Bug: On Exploiting Early Layers of Encoder Models for More Efficient Code Classification
#     Distinguished: False
#   Paper Name: Dynamic Data Fault Localization for Deep Neural Networks
#     Distinguished: False
#   Paper Name: Understanding the Bug Characteristics and Fix Strategies of Federated Learning Systems
#     Distinguished: False
#   Paper Name: Learning Program Semantics for Vulnerability Detection via Vulnerability-specific Inter-procedural Slicing
#     Distinguished: False
#   Paper Name: [Remote] DeepRover: A Query-efficient Blackbox Attack for Deep Neural Networks
#     Distinguished: False
#   Paper Name: LExecutor: Learning-Guided Execution
#     Distinguished: True
#   Paper Name: Software Architecture Recovery with Information Fusion
#     Distinguished: False
#   Paper Name: Evaluating Transfer Learning for Simplifying GitHub READMEs
#     Distinguished: False
#   Paper Name: [Remote] CodeMark: Imperceptible Watermarking for Code Datasets against Neural Code Completion Models
#     Distinguished: False
#
#
# Domain: domain_testing_analysis
#   Paper Name: Detecting JVM JIT Compiler Bugs via Exploring Two-Dimensional Input Spaces
#     Distinguished: False
#   Paper Name: JITfuzz: Coverage-guided Fuzzing for JVM Just-in-Time Compilers
#     Distinguished: False
#   Paper Name: Validating SMT Solvers via Skeleton Enumeration Empowered by Historical Bug-Triggering Inputs
#     Distinguished: False
#   Paper Name: Regression Fuzzing for Deep Learning Systems
#     Distinguished: False
#   Paper Name: Operand-Variation-Oriented Differential Analysis for Fuzzing Binding Calls in PDF Readers
#     Distinguished: False
#   Paper Name: Reachable Code Coverage
#     Distinguished: False
#   Paper Name: Learning Seed-Adaptive Mutation Strategies for Greybox Fuzzing
#     Distinguished: False
#   Paper Name: Improving Java Deserialization Gadget Chain Mining via Overriding-Guided Object Generation
#     Distinguished: False
#   Paper Name: Evaluating and Improving Hybrid Fuzzing
#     Distinguished: False
#   Paper Name: ECSTATIC: An Extensible Framework for Testing and Debugging Configurable Static Analysis
#     Distinguished: False
#   Paper Name: Responsibility in Context: On Applicability of Slicing in Semantic Regression Analysis
#     Distinguished: False
#   Paper Name: Does the Stream API Benefit from Special Debugging Facilities? A Controlled Experiment on Loops and Streams with Specific Debuggers
#     Distinguished: False
#   Paper Name: Fonte: Finding Bug Inducing Commits from Failures
#     Distinguished: False
#   Paper Name: Detecting Memory Errors in Python Native Code by Tracking Object Lifecycle with Reference Count
#     Distinguished: False
#   Paper Name: PERFCE: Performance Debugging on Databases with Chaos Engineering-Enhanced Causality Analysis
#     Distinguished: False
#   Paper Name: The MAP metric in Information Retrieval Fault Localization
#     Distinguished: False
#   Paper Name: Eiffel: Inferring Input Ranges of Significant Floating-point Errors via Polynomial Extrapolation
#     Distinguished: False
#   Paper Name: Information Retrieval-based Fault Localization for Concurrent Programs
#     Distinguished: False
#   Paper Name: BADGE: Prioritizing UI Events with Hierarchical Multi-Armed Bandits for Automated UI Testing
#     Distinguished: False
#   Paper Name: Efficiency Matters: Speeding Up Automated Testing with GUI Rendering Inference
#     Distinguished: True
#   Paper Name: CodaMOSA: Escaping Coverage Plateaus in Test Generation with Pre-trained Large Language Models
#     Distinguished: False
#   Paper Name: When and Why Test Generators for Deep Learning Produce Invalid Inputs: an Empirical Study
#     Distinguished: False
#   Paper Name: Fuzzing Automatic Differentiation in Deep-Learning Libraries
#     Distinguished: False
#   Paper Name: Lightweight Approaches to DNN Regression Error Reduction: An Uncertainty Alignment Perspective
#     Distinguished: False
#   Paper Name: Revisiting Neuron Coverage for DNN Testing: A Layer-Wise and Distribution-Aware Criterion
#     Distinguished: False
#   Paper Name: Aries: Efficient Testing of Deep Neural Networks via Labeling-Free Accuracy Estimation
#     Distinguished: False
#   Paper Name: CC: Causality-Aware Coverage Criterion for Deep Neural Networks
#     Distinguished: False
#   Paper Name: Balancing Effectiveness and Flakiness of Non-Deterministic Machine Learning Tests
#     Distinguished: False
#   Paper Name: Many-Objective Reinforcement Learning for Online Testing of DNN-Enabled Systems
#     Distinguished: False
#   Paper Name: Reliability Assurance for Deep Neural Network Architectures Against Numerical Defects
#     Distinguished: False
#   Paper Name: Data-driven Recurrent Set Learning For Non-termination Analysis
#     Distinguished: False
#   Paper Name: Compiling Parallel Symbolic Execution with Continuations
#     Distinguished: False
#   Paper Name: Verifying Data Constraint Equivalence in FinTech Systems
#     Distinguished: False
#   Paper Name: Tolerate Control-Flow Changes for Sound Data Race Prediction
#     Distinguished: False
#   Paper Name: Fill in the Blank: Context-aware Automated Text Input Generation for Mobile GUI Testing
#     Distinguished: False
#   Paper Name: Detecting Dialog-Related Keyboard Navigation Failures in Web Applications
#     Distinguished: False
#   Paper Name: COLUMBUS: Android App Testing Through Systematic Callback Exploration
#     Distinguished: False
#   Paper Name: GameRTS: A Regression Testing Framework for Video Games
#     Distinguished: False
#   Paper Name: Test Selection for Unified Regression Testing
#     Distinguished: False
#   Paper Name: ATM: Black-box Test Case Minimization based on Test Code Similarity and Evolutionary Search
#     Distinguished: False
#   Paper Name: Measuring and Mitigating Gaps in Structural Testing
#     Distinguished: False
#   Paper Name: Compiler Test-Program Generation via Memoized Configuration Search
#     Distinguished: False
#   Paper Name: Generating Test Databases for Database-Backed Applications
#     Distinguished: False
#   Paper Name: Testing Database Engines via Query Plan Guidance
#     Distinguished: True
#   Paper Name: Testing Database Systems via Differential Query Execution
#     Distinguished: False
#   Paper Name: Coverage Guided Fault Injection for Cloud Systems
#     Distinguished: False
#   Paper Name: Diver: Oracle-Guided SMT Solver Testing with Unrestricted Random Mutations
#     Distinguished: False
#   Paper Name: DuetCS: Code Style Transfer through Generation and Retrieval
#     Distinguished: False
#   Paper Name: MTTM: Metamorphic Testing for Textual Content Moderation Software
#     Distinguished: False
#   Paper Name: Metamorphic Shader Fusion for Testing Graphics Shader Compilers
#     Distinguished: False
#   Paper Name: MorphQ: Metamorphic Testing of the Qiskit Quantum Computing Platform
#     Distinguished: False
#   Paper Name: Finding Causally Different Tests for an Industrial Control System
#     Distinguished: False
#   Paper Name: Doppelganger Test Generation for Revealing Bugs in Autonomous Driving Software
#     Distinguished: False
#   Paper Name: Generating Realistic and Diverse Tests for LiDAR-Based Perception Systems
#     Distinguished: False
#   Paper Name: A First Look at the Inheritance-Induced Redundant Test Execution
#     Distinguished: False
#   Paper Name: Hypertesting of Programs: Theoretical Foundation and Automated Test Generation
#     Distinguished: False
#   Paper Name: Ripples of a Mutation — An Empirical Study of Propagation Effects in Mutation Testing
#     Distinguished: False
#   Paper Name: Fast Deterministic Black-box Context-free Grammar Inference
#     Distinguished: False
#   Paper Name: Do Automatic Test Generation Tools Generate Flaky Tests?
#     Distinguished: False
#   Paper Name: Deep Combination of CDCL(T) and Local Search for Satisfiability Modulo Non-Linear Integer Arithmetic Theory
#     Distinguished: False
#   Paper Name: Uncover the Premeditated Attacks: Detecting Exploitable Reentrancy Vulnerabilities by Identifying Attacker Contracts
#     Distinguished: False
#   Paper Name: Practical Non-Intrusive GUI Exploration Testing with Visual-based Robotic Arms
#     Distinguished: False
#   Paper Name: Concrete Constraint Guided Symbolic Execution
#     Distinguished: False
#   Paper Name: Improving Testing Behavior by Gamifying IntelliJ
#     Distinguished: False
#   Paper Name: SCTrans: Constructing a Large Public Scenario Dataset for Simulation Testing of Autonomous Driving Systems
#     Distinguished: False
#   Paper Name: Curiosity-Driven Testing for Sequential Decision-Making Process
#     Distinguished: False
#   Paper Name: Detecting Logic Bugs in Graph Database Management Systems via Injective and Surjective Graph Pattern Transformation
#     Distinguished: False
#   Paper Name: [Remote] CAmpactor: A Novel and Effective Local Search Algorithm for Optimizing Pairwise Covering Arrays
#     Distinguished: False
#   Paper Name: Accelerating Continuous Integration with Parallel Batch Testing
#     Distinguished: False
#   Paper Name: DistXplore: Distribution-guided Testing for Evaluating and Enhancing Deep Learning Systems
#     Distinguished: False
#   Paper Name: Statfier: Automated Testing of Static Analyzers via Semantic-preserving Program Transformations
#     Distinguished: False
#   Paper Name: Contextual Predictive Mutation Testing
#     Distinguished: False
#   Paper Name: MuAkka: Mutation Testing for Actor Concurrency in Akka Using Real-World Bugs
#     Distinguished: False
#   Paper Name: [Remote] Heterogeneous Testing for Coverage Profilers Empowered with Debugging Support
#     Distinguished: False
#   Paper Name: NeuRI: Diversifying DNN Generation via Inductive Rule Inference
#     Distinguished: True
#   Paper Name: Outage-Watch: Early Prediction of Outages using Extreme Event Regularizer
#     Distinguished: False
#   Paper Name: Code Coverage Criteria for Asynchronous Programs
#     Distinguished: False
#   Paper Name: EtherDiffer: Differential Testing on RPC Services of Ethereum Nodes
#     Distinguished: False
#   Paper Name: [Remote] API-Knowledge Aware Search-based Software Testing: Where, What and How
#     Distinguished: False
#   Paper Name: Evaluating and Improving ChatGPT for Unit Test Generation
#     Distinguished: False
#   Paper Name: Bounding Random Test Set Size with Computational Learning Theory
#     Distinguished: False
#   Paper Name: COSTELLO: Contrastive Testing for Embedding-based Large Language Model as a Service Embeddings
#     Distinguished: False
#   Paper Name: FeatMaker: Automated Feature Engineering for Search Strategy of Symbolic Execution
#     Distinguished: False
#   Paper Name: Metamorphic Testing of Secure Multi-Party Computation (MPC) Compilers
#     Distinguished: False
#   Paper Name: Mobile Bug Report Reproduction via Global Search on the App UI Model
#     Distinguished: False
#   Paper Name: Finding and Understanding Defects in Static Analyzers by Constructing Automated Oracles
#     Distinguished: False
#   Paper Name: A Miss Is as Good as A Mile: Metamorphic Testing for Deep Learning Operators
#     Distinguished: False
#   Paper Name: Java JIT Testing with Template Extraction
#     Distinguished: False
#   Paper Name: Partial Solution Based Constraint Solving Cache in Symbolic Execution
#     Distinguished: False
#   Paper Name: Natural Symbolic Execution-based Testing for Big Data Analytics
#     Distinguished: False
#   Paper Name: MTAS: A Reference-Free Approach for Evaluating Abstractive Summarization Systems
#     Distinguished: False
#   Paper Name: Inline Tests
#     Distinguished: False
#   Paper Name: Sorry, I don't Understand: Improving Voice User Interface Testing
#     Distinguished: False
#   Paper Name: VITAS : Guided Model-based VUI Testing of VPA Apps
#     Distinguished: False
#   Paper Name: Auto Off-Target: Enabling Thorough and Scalable Testing for Complex Software Systems
#     Distinguished: False
#   Paper Name: Natural Test Generation for Precise Testing of Question Answering Software
#     Distinguished: False
#   Paper Name: Selectively Combining Multiple Coverage Goals in Search-Based Unit Test Generation
#     Distinguished: False
#   Paper Name: PredART: Towards Automatic Oracle Prediction of Object Placements in Augmented Reality Testing
#     Distinguished: False
#   Paper Name: Neuroevolution-Based Generation of Tests and Oracles for Games
#     Distinguished: False
#   Paper Name: Learning to Construct Better Mutation Faults
#     Distinguished: True
#   Paper Name: Differentially Testing Database Transactions for Fun and Profit
#     Distinguished: False
#   Paper Name: CrashTranslator: Automatically Reproducing Mobile Application Crashes Directly from Stack Trace
#     Distinguished: False
#   Paper Name: Reorder Pointer Flow in Sound Concurrency Bug Prediction
#     Distinguished: False
#   Paper Name: Object Graph Programming
#     Distinguished: False
#   Paper Name: Semantic Analysis of Macro Usage for Portability
#     Distinguished: False
#   Paper Name: Trace-based Multi-Dimensional Root Cause Localization of Performance Issues in Microservice Systems
#     Distinguished: False
#   Paper Name: ReClues: Representing and indexing failures in parallel debugging with program variables
#     Distinguished: False
#   Paper Name: PyAnalyzer: An Effective and Practical Approach for Dependency Extraction from Python Code
#     Distinguished: False
#   Paper Name: Detecting Automatic Software Plagiarism via Token Sequence Normalization
#     Distinguished: False
#   Paper Name: NuzzleBug: Debugging Block-Based Programs in Scratch
#     Distinguished: False
#   Paper Name: CERT: Finding Performance Issues in Database Systems Through the Lens of Cardinality Estimation
#     Distinguished: False
#   Paper Name: Optimistic Prediction of Synchronization-Reversal Data Races
#     Distinguished: False
#   Paper Name: Mozi: Discovering DBMS Bugs via Configuration-Based Equivalent Transformation
#     Distinguished: False
#   Paper Name: FlakeSync: Automatically Repairing Async Flaky Tests
#     Distinguished: False
#   Paper Name: Testing the Limits: Unusual Text Inputs Generation for Mobile App Crash Detection with Large Language Model
#     Distinguished: False
#   Paper Name: Towards Finding Accounting Errors in Smart Contracts
#     Distinguished: True
#   Paper Name: MultiTest: Physical-Aware Object Insertion for Testing Multi-sensor Fusion Perception Systems
#     Distinguished: False
#   Paper Name: JLeaks: A Featured Resource Leak Repository Collected From Hundreds of Open-Source Java Projects
#     Distinguished: False
#   Paper Name: S3C: Spatial Semantic Scene Coverage for Autonomous Vehicles
#     Distinguished: False
#   Paper Name: FlashSyn: Flash Loan Attack Synthesis via Counter Example Driven Approximation
#     Distinguished: False
#   Paper Name: Testing Graph Database Systems via Equivalent Query Rewriting
#     Distinguished: False
#   Paper Name: ROSInfer: Statically Inferring Behavioral Component Models for ROS-based Robotics Systems
#     Distinguished: False
#   Paper Name: Finding XPath Bugs in XML Document Processors via Differential Testing
#     Distinguished: False
#   Paper Name: Sedar: Obtaining High-Quality Seeds for DBMS Fuzzing via Cross-DBMS SQL Transfer
#     Distinguished: False
#   Paper Name: Automatically Detecting Reflow Accessibility Issues in Responsive Web Pages
#     Distinguished: False
#   Paper Name: Crossover in Parametric Fuzzing
#     Distinguished: False
#   Paper Name: SpecBCFuzz: Fuzzing LTL Solvers with Boundary Conditions
#     Distinguished: False
#   Paper Name: EDEFuzz: A Web API Fuzzer for Excessive Data Exposures
#     Distinguished: True
#   Paper Name: ECFuzz: Effective Configuration Fuzzing for Large-Scale Systems
#     Distinguished: False
#   Paper Name: Are We There Yet? Unraveling the State-of-the-Art Smart Contract Fuzzers
#     Distinguished: False
#   Paper Name: RPG: Rust Library Fuzzing with Pool-based Fuzz Target Generation and Generic Support
#     Distinguished: False
#   Paper Name: Extrapolating Coverage Rate in Greybox Fuzzing
#     Distinguished: False
#   Paper Name: FuzzInMem: Fuzzing Programs via In-memory Structures
#     Distinguished: False
#   Paper Name: Fuzz4All: Universal Fuzzing with Large Language Models
#     Distinguished: False
#   Paper Name: Enhancing Coverage-guided Fuzzing via Phantom Program
#     Distinguished: False
#   Paper Name: Co-Dependence Aware Fuzzing for Dataflow-based Big Data Analytics
#     Distinguished: False
#   Paper Name: SJFuzz: Seed & Mutator Scheduling for JVM Fuzzing
#     Distinguished: False
#   Paper Name: Metamong: Detecting Render-update Bugs in Web Browsers through Fuzzing
#     Distinguished: False
#   Paper Name: Property-based Fuzzing for Finding Data Manipulation Errors in Android Apps
#     Distinguished: False
#   Paper Name: Leveraging Hardware Probes and Optimizations for Accelerating Fuzz Testing of Heterogeneous Applications
#     Distinguished: False
#   Paper Name: NaNofuzz: A Usable Tool for Automatic Test Generation
#     Distinguished: False
#   Paper Name: [Remote] A Generative and Mutational Approach for Synthesizing Bug-exposing Test Cases to Guide Compiler Fuzzing
#     Distinguished: False
#   Paper Name: Evaluating Directed Fuzzers: Are We Heading in the Right Direction?
#     Distinguished: False
#   Paper Name: LawBreaker: An Approach for Specifying Traffic Laws and Fuzzing Autonomous Vehicles
#     Distinguished: False
#   Paper Name: Fuzzle: Making a Puzzle for Fuzzers
#     Distinguished: True
#   Paper Name: HTFuzz: Heap Operation Sequence Sensitive Fuzzing
#     Distinguished: False
#   Paper Name: Efficient Greybox Fuzzing to Detect Memory Errors
#     Distinguished: True
#   Paper Name: Griffin: Grammar-Free DBMS Fuzzing
#     Distinguished: False
#   Paper Name: So Many Fuzzers, So Little Time - Experience from Evaluating Fuzzers on the Contiki-NG Network (Hay)Stack
#     Distinguished: False
#   Paper Name: FuzzerAid: Grouping Fuzzed Crashes Based On Fault Signatures
#     Distinguished: False
#   Paper Name: QATest: A Uniform Fuzzing Framework for Question Answering Systems
#     Distinguished: True
#   Paper Name: Effectively Generating Vulnerable Transaction Sequences in Smart Contracts with Reinforcement Learning-guided Fuzzing
#     Distinguished: False
#   Paper Name: MLIRSmith: Random Program Generation for Fuzzing MLIR Compiler Infrastructure
#     Distinguished: False
#   Paper Name: Thunderkaller: Profiling and Improving the Performance of Syzkaller
#     Distinguished: False
#   Paper Name: PHYFU: Fuzzing Modern Physics Simulation Engines
#     Distinguished: True
#   Paper Name: NaturalFuzz: Natural Input Generation for Big Data Analytics
#     Distinguished: False
#   Paper Name: Prompting Is All Your Need: Automated Android Bug Replay with Large Language Models
#     Distinguished: False
#   Paper Name: Towards Reliable AI: Adequacy Metrics for Ensuring the Quality of System-level Testing of Autonomous Vehicles
#     Distinguished: False
#   Paper Name: Learning-based Widget Matching for Migrating GUI Test Cases
#     Distinguished: False
#   Paper Name: Large Language Models are Edge-Case Generators: Crafting Unusual Programs for Fuzzing Deep Learning Libraries
#     Distinguished: False
#   Paper Name: Deeply Reinforcing Android GUI Testing with Deep Reinforcement Learning
#     Distinguished: False
#   Paper Name: CIT4DNN: Generating Diverse and Rare Inputs for Neural Networks Using Latent Space Combinatorial Testing
#     Distinguished: False
#   Paper Name: Knowledge Graph Driven Inference Testing for Question Answering Software
#     Distinguished: False
#   Paper Name: DeepSample: DNN sampling-based testing for operational accuracy assessment
#     Distinguished: False
#   Paper Name: MAFT: Efficient Model-Agnostic Fairness Testing for Deep Neural Networks via Zero-Order Gradient Search
#     Distinguished: False
#   Paper Name: Call Me Maybe: Using NLP to Automatically Generate Unit Test Cases Respecting Temporal Constraints
#     Distinguished: False
#   Paper Name: CoditT5: Pretraining for Source Code and Natural Language Editing
#     Distinguished: False
#   Paper Name: Is this Change the Answer to that Problem? Correlating Descriptions of Bug and Code Changes for Evaluating Patch Correctness
#     Distinguished: False
#   Paper Name: LISSA: Lazy Initialization with Specialized Solver Aid
#     Distinguished: False
#   Paper Name: SymFusion: Hybrid Instrumentation for Concolic Execution
#     Distinguished: False
#   Paper Name: Scalable Sampling of Highly-Configurable Systems: Generating Random Instances of the Linux Kernel
#     Distinguished: False
#   Paper Name: Prioritized Constraint-Aided Dynamic Partial-Order Reduction
#     Distinguished: False
#   Paper Name: Nuances are the Key: Unlocking ChatGPT to Find Failure-Inducing Tests with Differential Prompting
#     Distinguished: False
#   Paper Name: Robin: A Novel Method to Produce Robust Interpreters for Deep Learning-Based Code Classifiers
#     Distinguished: False
#   Paper Name: The Devil is in the Tails: How Long-Tailed Code Distributions Impact Large Language Models
#     Distinguished: False
#   Paper Name: CertPri: Certifiable Prioritization for Deep Neural Networks via Movement Cost in Feature Space
#     Distinguished: False
#   Paper Name: ATOM: Automated Black-Box Testing of Multi-Label Image Classification Systems
#     Distinguished: False
#   Paper Name: Generative Model-Based Testing on Decision-Making Policies
#     Distinguished: False
#   Paper Name: Causality-Aided Trade-off Analysis for Machine Learning Fairness
#     Distinguished: False
#   Paper Name: Cell2Doc: ML Pipeline for Generating Documentation in Computational Notebooks
#     Distinguished: False
#   Paper Name: Mutation-based Fault Localization of Deep Neural Networks
#     Distinguished: True
#   Paper Name: AutoConf : Automated Configuration of Unsupervised Learning Systems using Metamorphic Testing and Bayesian Optimization
#     Distinguished: False
#   Paper Name: An Intentional Forgetting-Driven Self-Healing Method For Deep Reinforcement Learning Systems
#     Distinguished: False
#   Paper Name: AutoLog: A Log Sequence Synthesis Framework for Anomaly Detection
#     Distinguished: False
#   Paper Name: Aster: Automatic Speech Recognition System Accessibility Testing for Stutterers
#     Distinguished: False
#   Paper Name: Software Entity Recognition with Noise-Robust Learning
#     Distinguished: False
#   Paper Name: DCLink: Bridging Data Constraint Changes and Implementations in FinTech Systems
#     Distinguished: False
#   Paper Name: Systematically Detecting Packet Validation Vulnerabilities in Embedded Network Stacks
#     Distinguished: False
#   Paper Name: WADIFF: A Differential Testing Framework for WebAssembly Runtimes
#     Distinguished: False
#   Paper Name: VRGuide: Efficient Testing of Virtual Reality Scenes via Dynamic Cut Coverage
#     Distinguished: False
#   Paper Name: Bridging the Gap between Academia and Industry in Machine Learning Software Defect Prediction: Thirteen Considerations
#     Distinguished: False
#   Paper Name: Identify and Update Test Cases when Production Code Changes: A Transformer-based Approach
#     Distinguished: False
#   Paper Name: Revisiting and Improving Retrieval-Augmented Deep Assertion Generation
#     Distinguished: False
#   Paper Name: QuraTest: Integrating Quantum Specific Features in Quantum Program Testing
#     Distinguished: False
#   Paper Name: LEAP: Efficient and Automated Test Method for NLP Software
#     Distinguished: False
#   Paper Name: An Image is Worth a Thousand Toxic Words: A Metamorphic Testing Framework for Content Moderation Software
#     Distinguished: False
#   Paper Name: CoMSA: A modeling driven sampling approach for configuration performance testing
#     Distinguished: False
#   Paper Name: Effective Concurrency Testing for Go via Directional Primitive-constrained Interleaving Exploration
#     Distinguished: False
#   Paper Name: Fuzzing for CPS Mutation Testing
#     Distinguished: False
#   Paper Name: Evaluating the Impact of Experimental Assumptions in Automated Fault Localization
#     Distinguished: False
#   Paper Name: Locating Framework-specific Crashing Faults with Compact and Explainable Candidate Set
#     Distinguished: False
#   Paper Name: PExReport: Automatic Creation of Pruned Executable Cross-Project Failure Reports
#     Distinguished: False
#   Paper Name: RAT: A Refactoring-Aware Traceability Model for Bug Localization
#     Distinguished: False
#   Paper Name: How Useful is Code Change Information for Fault Localization in Continuous Integration?
#     Distinguished: False
#   Paper Name: Evolving Ranking-Based Failure Proximities for Better Clustering in Fault Isolation
#     Distinguished: False
#   Paper Name: ICEBAR: Feedback-Driven Iterative Repair of Alloy Specifications
#     Distinguished: False
#   Paper Name: Repairing Failure-inducing Inputs with Input Reflection
#     Distinguished: False
#   Paper Name: TransplantFix: Graph Differencing-based Code Transplantation for Automated Program Repair
#     Distinguished: False
#   Paper Name: StandUp4NPR: Standardizing Setup for Empirically Comparing Neural Program Repair Systems
#     Distinguished: False
#   Paper Name: A Comparative Study of Transformer-based Neural Text Representation Techniques on Bug Triaging
#     Distinguished: False
#   Paper Name: Neural SZZ Algorithm
#     Distinguished: False
#   Paper Name: How to Train Your Neural Bug Detector: Artificial vs Real Bugs
#     Distinguished: False
#   Paper Name: Detection of Java Basic Thread Misuses Based on Static Event Analysis
#     Distinguished: False
#   Paper Name: FLUX: Finding Bugs with LLVM IR Based Unit Test Crossovers
#     Distinguished: False
#   Paper Name: How Do We Read Formal Claims? Eye-Tracking and the Cognition of Proofs about Algorithms
#     Distinguished: False
#   Paper Name: Which of My Assumptions are Unnecessary for Realizability and Why Should I Care?
#     Distinguished: False
#   Paper Name: RepresentThemAll: A Universal Learning Representation of Bug Reports
#     Distinguished: False
#   Paper Name: Demystifying Exploitable Bugs in Smart Contracts
#     Distinguished: False
#   Paper Name: Understanding and Detecting On-the-Fly Configuration Bugs
#     Distinguished: True
#   Paper Name: Explaining Software Bugs Leveraging Code Structures in Neural Machine Translation
#     Distinguished: False
#   Paper Name: Detecting Exception Handling Bugs in C++ Programs
#     Distinguished: False
#   Paper Name: Learning to Boost Disjunctive Static Bug-Finders
#     Distinguished: False
#   Paper Name: Predicting Bugs by Monitoring Developers During Task Execution
#     Distinguished: False
#   Paper Name: Detecting Isolation Bugs via Transaction Oracle Construction
#     Distinguished: False
#   Paper Name: SmallRace: Static Race Detection for Dynamic Languages - A Case on Smalltalk
#     Distinguished: False
#   Paper Name: DLInfer: Deep Learning with Static Slicing for Python Type Inference
#     Distinguished: False
#   Paper Name: ViolationTracker: Building Precise Histories for Static Analysis Violations
#     Distinguished: False
#   Paper Name: Symbol-Specific Sparsification of Interprocedural Distributive Environment Problems
#     Distinguished: False
#   Paper Name: A Framework For Inferring Properties of User-Defined Functions
#     Distinguished: False
#   Paper Name: RogueOne: Detecting Rogue Updates via Differential Data-flow Analysis Using Trust Domains
#     Distinguished: False
#   Paper Name: ACAV: A Framework for Automatic Causality Analysis in Autonomous Vehicle Accident Recordings
#     Distinguished: False
#   Paper Name: Efficiently Trimming the Fat: Streamlining Software Dependencies with Java Reflection and Dependency Analysis
#     Distinguished: False
#   Paper Name: LibAlchemy: A Two-Layer Persistent Summary Design for Taming Third-Party Libraries in Static Bug-Finding Systems
#     Distinguished: False
#   Paper Name: Is unsafe an Achilles' Heel? A Comprehensive Study of Safety Requirements in Unsafe Rust Programming
#     Distinguished: False
#   Paper Name: Generating REST API Specifications through Static Analysis
#     Distinguished: False
#   Paper Name: Precise Sparse Abstract Execution via Cross-Domain Interaction
#     Distinguished: False
#   Paper Name: MalwareTotal: Multi-Faceted and Sequence-Aware Bypass Tactics against Static Malware Detection
#     Distinguished: False
#   Paper Name: Semantic-Enhanced Static Vulnerability Detection in Baseband Firmware
#     Distinguished: True
#   Paper Name: CSChecker: Revisiting GDPR and CCPA Compliance of Cookie Banners on the Web
#     Distinguished: False
#   Paper Name: Raisin: Identifying Rare Sensitive Functions for Bug Detection
#     Distinguished: False
#   Paper Name: [Remote] Nezha: Interpretable Fine-Grained Root Causes Analysis for Microservices on Multi-Modal Observability Data
#     Distinguished: False
#   Paper Name: [Remote] DiagConfig: Configuration Diagnosis of Performance Violations in Configurable Software Systems
#     Distinguished: False
#   Paper Name: [Remote] Pre-training Code Representation with Semantic Flow Graph for Effective Bug Localization
#     Distinguished: False
#   Paper Name: [Remote] A Practical Human Labeling Method for Online Just-in-Time Software Defect Prediction
#     Distinguished: False
#   Paper Name: Automata-based Trace Analysis for Aiding Diagnosing GUI Testing Tools for Android
#     Distinguished: False
#   Paper Name: DeepDebugger: An Interactive Time-Travelling Debugging Approach for Deep Classifiers
#     Distinguished: False
#   Paper Name: TransMap: Pinpointing Mistakes in Neural Code Translation
#     Distinguished: False
#   Paper Name: Dynamic Prediction of Delays in Software Projects Using Delay Patterns and Bayesian Modeling
#     Distinguished: False
#   Paper Name: Commit-level, Neural Vulnerability Detection and Assessment
#     Distinguished: False
#   Paper Name: [Remote] Mining Resource-Operation Knowledge to Support Resource Leak Detection
#     Distinguished: False
#   Paper Name: A Quantitative and Qualitative Evaluation of LLM-based Explainable Fault Localization
#     Distinguished: False
#   Paper Name: BARO: Robust Root Cause Analysis for Microservices via Multivariate Bayesian Online Change Point Detection
#     Distinguished: False
#   Paper Name: ChangeRCA: Finding Root Causes from Software Changes in Large Online Systems
#     Distinguished: False
#   Paper Name: Towards Better Graph Neural Network-based Fault Localization Through Enhanced Code Representation
#     Distinguished: False
#   Paper Name: State Merging with Quantifiers in Symbolic Execution
#     Distinguished: False
#   Paper Name: Engineering a Formally Verified Automated Bug Finder
#     Distinguished: False
#   Paper Name: Speeding up SMT Solving via Compiler Optimization
#     Distinguished: True
#   Paper Name: [Remote] Detecting Atomicity Violations in Interrupt-Driven Programs via Interruption Points Selecting and Delayed ISR-Triggering
#     Distinguished: False
#   Paper Name: A Transferability Study of Interpolation-Based Hardware Model Checking to Software Verification
#     Distinguished: True
#   Paper Name: Automated Feedback Generation for Competition-Level Code
#     Distinguished: False
#   Paper Name: CrystalBLEU: Precisely and Efficiently Measuring the Similarity of Code
#     Distinguished: True
#   Paper Name: Low-Resources Project-Specific Code Summarization
#     Distinguished: False
#   Paper Name: SA4U: Practical Static Analysis for Unit Type Error Detection
#     Distinguished: False
#   Paper Name: AST-Probe: Recovering abstract syntax trees from hidden representations of pre-trained language models
#     Distinguished: False
#   Paper Name: Static Type Recommendation for Python
#     Distinguished: False
#   Paper Name: Prompt-tuned Code Language Model as a Neural Knowledge Base for Type Inference in Statically-Typed Partial Code
#     Distinguished: False
#   Paper Name: Jasmine: A Static Analysis Framework for Spring Core Technologies
#     Distinguished: False
#   Paper Name: Automatic Comment Generation via Multi-Pass Deliberation
#     Distinguished: False
#   Paper Name: Provably Tightest Linear Approximation for Robustness Verification of Sigmoid-like Neural Networks
#     Distinguished: False
#   Paper Name: Efficient Synthesis of Method Call Sequences for Test Generation and Bounded Verification
#     Distinguished: False
#   Paper Name: Detecting Semantic Code Clones by Building AST-based Markov Chains Model
#     Distinguished: False
#   Paper Name: Tseitin or not Tseitin? The Impact of CNF Transformations on Feature-Model Analyses
#     Distinguished: False
#   Paper Name: Finding and Understanding Incompleteness Bugs in SMT Solvers
#     Distinguished: False
#   Paper Name: Checking LTL Satisfiability via End-to-end Learning
#     Distinguished: False
#   Paper Name: QVIP: An ILP-based Formal Verification Approach for Quantized Neural Networks
#     Distinguished: False
#   Paper Name: Concrat: An Automatic C-to-Rust Lock API Translator for Concurrent Programs
#     Distinguished: False
#   Paper Name: Triggers for Reactive Synthesis Specifications
#     Distinguished: False
#   Paper Name: Using Reactive Synthesis: An End-to-End Exploratory Case Study
#     Distinguished: False
#   Paper Name: Syntax and Domain Aware Model for Unsupervised Program Translation
#     Distinguished: False
#   Paper Name: Better Automatic Program Repair by Using Bug Reports and Tests Together
#     Distinguished: False
#   Paper Name: CCTEST: Testing and Repairing Code Completion Systems
#     Distinguished: False
#   Paper Name: KNOD: Domain Knowledge Distilled Tree Decoder for Automated Program Repair
#     Distinguished: False
#   Paper Name: Rete: Learning Namespace Representation for Program Repair
#     Distinguished: True
#   Paper Name: Impact of Code Language Models on Automated Program Repair
#     Distinguished: False
#   Paper Name: Tare: Type-Aware Neural Program Repair
#     Distinguished: False
#   Paper Name: Template-based Neural Program Repair
#     Distinguished: False
#   Paper Name: Automated Repair of Programs from Large Language Models
#     Distinguished: False
#   Paper Name: Automated Program Repair in the Era of Large Pre-trained Language Models
#     Distinguished: False
#   Paper Name: Heterogeneous Anomaly Detection for Software Systems via Semi-supervised Cross-modal Attention
#     Distinguished: False
#   Paper Name: Recommending Root-Cause and Mitigation Steps for Cloud Incidents using Large Language Models
#     Distinguished: False
#   Paper Name: Eadro: An End-to-End Troubleshooting Framework for Microservices on Multi-source Data
#     Distinguished: False
#   Paper Name: LogReducer: Identify and Reduce Log Hotspots in Kernel on the Fly
#     Distinguished: False
#   Paper Name: DStream: A Streaming-Based Highly Parallel IFDS Framework
#     Distinguished: False
#   Paper Name: (Partial) Program Dependence Learning
#     Distinguished: False
#   Paper Name: MirrorTaint: Practical Non-intrusive Dynamic Taint Tracking for JVM-based Microservice Systems
#     Distinguished: False
#   Paper Name: Domain Knowledge Matters: Improving Prompts with Fix Templates for Repairing Python Type Errors
#     Distinguished: False
#   Paper Name: VeRe: Verification Guided Synthesis for Repairing Deep Neural Networks
#     Distinguished: False
#   Paper Name: Automated Program Repair, What Is It Good For? Not Absolutely Nothing!
#     Distinguished: False
#   Paper Name: Practical Program Repair via Preference-based Ensemble Strategy
#     Distinguished: False
#   Paper Name: Learning and Repair of Deep Reinforcement Learning Policies from Fuzz-Testing Data
#     Distinguished: False
#   Paper Name: BinAug: Enhancing Binary Similarity Analysis with Low-Cost Input Repairing
#     Distinguished: False
#   Paper Name: Constraint Based Program Repair for Persistent Memory Bugs
#     Distinguished: False
#   Paper Name: RUNNER: Responsible UNfair NEuron Repair for Enhancing Deep Neural Network Fairness
#     Distinguished: False
#   Paper Name: ITER: Iterative Neural Repair for Multi-Location Patches
#     Distinguished: False
#   Paper Name: Out of Context: How important is Local Context in Neural Program Repair?
#     Distinguished: False
#   Paper Name: Out of Sight, Out of Mind: Better Automatic Vulnerability Repair by Broadening Input Ranges and Sources
#     Distinguished: False
#   Paper Name: Strengthening Supply Chain Security with Fine-grained Safe Patch Identification
#     Distinguished: False
#   Paper Name: Comprehensive Semantic Repair of Obsolete GUI Test Scripts for Mobile Applications
#     Distinguished: False
#   Paper Name: Exploring Experiences with Automated Program Repair in Practice
#     Distinguished: False
#   Paper Name: PyTy: Repairing Static Type Errors in Python
#     Distinguished: False
#   Paper Name: Rust-lancet: Automated Ownership-Rule-Violation Fixing with Behavior Preservation
#     Distinguished: False
#   Paper Name: The Plastic Surgery Hypothesis in the Era of Large Language Models
#     Distinguished: False
#   Paper Name: GAMMA: Revisiting Template-based Automated Program Repair via Mask Prediction
#     Distinguished: False
#   Paper Name: An Empirical Study on Fine-tuning Large Language Models of Code for Automated Program Repair
#     Distinguished: True
#   Paper Name: LeakPair: Proactive Repairing of Memory Leaks in Single Page Web Applications
#     Distinguished: True
#   Paper Name: Automated Fixing of Web UI Tests via Iterative Element Matching
#     Distinguished: False
#   Paper Name: OrdinalFix: Fixing Compilation Errors via Shortest-Path CFL Reachability with Attribute Checking
#     Distinguished: False
#   Paper Name: RAP-Gen: Retrieval-Augmented Patch Generation with CodeT5 for Automatic Program Repair
#     Distinguished: False
#   Paper Name: From Leaks to Fixes: Automated Repairs for Resource Leak Warnings
#     Distinguished: False
#   Paper Name: Copiloting the Copilots: Fusing Large Language Models with Completion Engines for Automated Program Repair
#     Distinguished: False
#   Paper Name: SmartFix: Fixing Vulnerable Smart Contracts by Accelerating Generate-and-Verify Repair using Statistical Models
#     Distinguished: False
#   Paper Name: Automatically Resolving Dependency-Conflict Building Failures via Behavior-Consistent Loosening of Library Version Constraints
#     Distinguished: False
#   Paper Name: A Large-scale Empirical Review of Patch Correctness Checking Approaches
# ...
#     Distinguished: False
#   Paper Name: A Longitudinal Study of Student Contributions to OSS vs. OSS4SG with a Lightweight Intervention
#     Distinguished: True
#   Paper Name: Do CONTRIBUTING files provide information about OSS newcomers' onboarding barriers?
#     Distinguished: False
#   Paper Name: How Early Participation Determines Long-Term Sustained Activity in GitHub Projects?
#     Distinguished: False
#   Paper Name: Matching Skills, Past Collaboration, and Limited Competition: Modeling When Open-Source Projects Attract Contributors
#     Distinguished: False
#   Paper Name: [Remote] Towards Automated Detection of Unethical Behavior in Open-source Software Projects
#     Distinguished: False
#   Paper Name: Flow experience in software engineering
#     Distinguished: False
#   Paper Name: Building and Sustaining Ethnically, Racially, and Gender Diverse Software Engineering Teams: A Study at Google
#     Distinguished: False
#   Paper Name: A Case Study of Developer Bots: Motivations, Perceptions, and Challenges
#     Distinguished: False
#   Paper Name: "We Feel Like We're Winging It": A Study on Navigating Open-Source Dependency Abandonment
#     Distinguished: False
#   Paper Name: How Practitioners Expect Code Completion?
#     Distinguished: False
#   Paper Name: "The Law Doesn’t Work Like a Computer": Exploring Software Licensing Issues Faced by Legal Practitioners
#     Distinguished: True
#   Paper Name: AI-assisted Code Authoring at Scale: Fine-tuning, deploying, and mixed methods evaluation
#     Distinguished: False
#   Paper Name: An Analysis of the Costs and Benefits of Autocomplete in IDEs
#     Distinguished: False
#   Paper Name: Shadows in the Interface: A Comprehensive Study on Dark Patterns
#     Distinguished: False
#   Paper Name: Can GPT-4 Replicate Empirical Software Engineering Research?
#     Distinguished: False
#   Paper Name: Do Code Generation Models Think Like Us? - A Study of Attention Alignment between Large Language Models and Human Programmers
#     Distinguished: False
#   Paper Name: Do Words Have Power? Understanding and Fostering Civility in Code Review Discussion
#     Distinguished: False
#   Paper Name: Effective Teaching through Code Reviews: Patterns and Anti-Patterns
#     Distinguished: False
#   Paper Name: An empirical study on code review activity prediction in practice
#     Distinguished: False
#   Paper Name: Rocks Coding, Not Development–A Human-Centric, Experimental Evaluation of LLM-Supported SE Tasks
#     Distinguished: False
#   Paper Name: Beyond Code Generation: An Observational Study of ChatGPT Usage in Software Engineering Practice
#     Distinguished: False
#   Paper Name: How to Gain Commit Rights in Modern Top Open Source Communities?
#     Distinguished: False
#   Paper Name: How does Simulation-based Testing for Self-driving Cars match Human Perception?
#     Distinguished: False
#   Paper Name: Constructing a System Knowledge Graph of User Tasks and Failures from Bug Reports to Support Soap Opera Testing
#     Distinguished: False
#   Paper Name: Data Augmentation for Improving Emotion Recognition in Software Engineering Communication
#     Distinguished: False
#   Paper Name: On the Relationship Between Code Verifiability and Understandability
#     Distinguished: False
#   Paper Name: Towards Greener Yet Powerful Code Generation via Quantization: An Empirical Study
#     Distinguished: False
#   Paper Name: [Remote] Understanding the topics and challenges of GPU programming by classifying and analyzing Stack Overflow posts
#     Distinguished: False
#   Paper Name: [Remote] Software Architecture in Practice: Challenges and Opportunities
#     Distinguished: False
#   Paper Name: An Empirical Study on Focal Methods in Deep-Learning-Based Approaches for Assertion Generation
#     Distinguished: False
#   Paper Name: Less Cybersickness, Please: Demystifying and Detecting Stereoscopic Visual Inconsistencies in Virtual Reality Applications
#     Distinguished: False
#   Paper Name: State Reconciliation Defects in Infrastructure as Code
#     Distinguished: False
#   Paper Name: Understanding and Detecting Annotation-induced Faults of Static Analyzers
#     Distinguished: False
#   Paper Name: Understanding the Impact of APIs Behavioral Breaking Changes on Client Applications
#     Distinguished: False
#   Paper Name: AROMA: Automatic Reproduction of Maven Artifacts
#     Distinguished: False
#
#
# Domain: domain_dependability_security
#   Paper Name: BFTDetector: Automatic Detection of Business Flow Tampering for Digital Content Service
#     Distinguished: False
#   Paper Name: FedSlice: Protecting Federated Learning Models from Malicious Participants with Model Slicing
#     Distinguished: False
#   Paper Name: PTPDroid: Detecting Violated User Privacy Disclosures to Third-Parties of Android Apps
#     Distinguished: False
#   Paper Name: AdHere: Automated Detection and Repair of Intrusive Ads
#     Distinguished: False
#   Paper Name: Bad Snakes: Understanding and Improving Python Package Index Malware Scanning
#     Distinguished: False
#   Paper Name: TAINTMINI: Detecting Flow of Sensitive Data in Mini-Programs with Static Taint Analysis
#     Distinguished: False
#   Paper Name: AChecker: Statically Detecting Smart Contract Access Control Vulnerabilities
#     Distinguished: False
#   Paper Name: Fine-grained Commit-level Vulnerability Type Prediction By CWE Tree Structure
#     Distinguished: False
#   Paper Name: VulGen: Realistic Vulnerability Generation Via Pattern Mining and Deep Learning
#     Distinguished: False
#   Paper Name: On-Demand Security Requirements Synthesis with Relational Generative Adversarial Networks (RelGAN)
#     Distinguished: False
#   Paper Name: Measuring Secure Coding Practice and Culture: A Finger Pointing at the Moon is not the Moon
#     Distinguished: False
#   Paper Name: What Challenges Do Developers Face About Checked-in Secrets in Software Artifacts?
#     Distinguished: False
#   Paper Name: Lejacon: A Lightweight and Efficient Approach to Java Confidential Computing on SGX
#     Distinguished: True
#   Paper Name: Keyword Extraction From Specification Documents for Planning Security Mechanisms
#     Distinguished: False
#   Paper Name: Towards More Practical Automation of Vulnerability Assessment
#     Distinguished: False
#   Paper Name: VGX: Large-Scale Sample Generation for Boosting Learning-Based Software Vulnerability Analyses
#     Distinguished: False
#   Paper Name: MalCertain: Enhancing Deep Neural Network Based Android Malware Detection by Tackling Prediction Uncertainty
#     Distinguished: False
#   Paper Name: Pre-training by Predicting Program Dependencies for Vulnerability Analysis Tasks
#     Distinguished: False
#   Paper Name: Investigating White-Box Attacks for On-Device Models
#     Distinguished: False
#   Paper Name: Towards Causal Deep Learning for Vulnerability Detection
#     Distinguished: False
#   Paper Name: MetaLog: Generalizable Cross-System Anomaly Detection from Logs with Meta-Learning
#     Distinguished: False
#   Paper Name: Coca: Improving and Explaining Graph Neural Network-Based Vulnerability Detection Systems
#     Distinguished: False
#   Paper Name: Improving Smart Contract Security with Contrastive Learning-based Vulnerability Detection
#     Distinguished: False
#   Paper Name: On the Effectiveness of Function-Level Vulnerability Detectors for Inter-Procedural Vulnerabilities
#     Distinguished: False
#   Paper Name: Marco: A Stochastic Asynchronous Concolic Explorer
#     Distinguished: False
#   Paper Name: Smart Contract and DeFi Security Tools: Do They Meet the Needs of Practitioners?
#     Distinguished: False
#   Paper Name: DocFlow: Extracting Taint Specifications from Software Documentation
#     Distinguished: False
#   Paper Name: Toward Improved Deep Learning-based Vulnerability Detection
#     Distinguished: False
#   Paper Name: Attention! Your Copied Data is Under Monitoring: A Systematic Study of Clipboard Usage in Android Apps
#     Distinguished: True
#   Paper Name: PonziGuard: Detecting Ponzi Schemes on Ethereum with Contract Runtime Behavior Graph (CRBG)
#     Distinguished: False
#   Paper Name: FuzzSlice: Pruning False Positives in Static Analysis Warnings through Function-Level Fuzzing
#     Distinguished: False
#   Paper Name: LibvDiff: Library Version Difference Guided OSS Version Identification in Binaries
#     Distinguished: False
#   Paper Name: An Empirical Study on Oculus Virtual Reality Applications: Security and Privacy Perspectives
#     Distinguished: False
#   Paper Name: Fairness Improvement with Multiple Protected Attributes: How Far Are We?
#     Distinguished: False
#   Paper Name: An Empirical Study of Data Disruption by Ransomware Attacks
#     Distinguished: False
#   Paper Name: A User-centered Security Evaluation of Copilot
#     Distinguished: False
#   Paper Name: Identifying Affected Libraries and Their Ecosystems for Open Source Software Vulnerabilities
#     Distinguished: False
#   Paper Name: Understanding Transaction Bugs in Database Systems
#     Distinguished: False
#   Paper Name: When Contracts Meets Crypto: Exploring Developers' Struggles with Ethereum Cryptographic APIs
#     Distinguished: False
#   Paper Name: Software Composition Analysis for Vulnerability Detection: An Empirical Study on Java Projects
#     Distinguished: False
#   Paper Name: Input-driven Dynamic Program Debloating for Code-reuse Attack Mitigation
#     Distinguished: False
#   Paper Name: [Remote] Comparison and Evaluation on Static Application Security Testing (SAST) Tools for Java
#     Distinguished: False
#   Paper Name: [Remote] TransRacer: Function Dependence-Guided Transaction Race Detection for Smart Contracts
#     Distinguished: True
#   Paper Name: Mate! Are You Really Aware? An Explainability-Guided Testing Framework for Robustness of Malware Detectors
#     Distinguished: True
#   Paper Name: Crystallizer: A Hybrid Path Analysis Framework To Aid in Uncovering Deserialization Vulnerabilities
#     Distinguished: False
#   Paper Name: ViaLin: Path-Aware Dynamic Taint Analysis for Android
#     Distinguished: False
#   Paper Name: [Remote] Distinguishing Look-Alike Innocent and Vulnerable Code by Subtle Semantic Representation Learning and Explanation
#     Distinguished: False
#   Paper Name: Reentrancy Vulnerability Detection and Localization: A Deep Learning Based Two-phase Approach
#     Distinguished: False
#   Paper Name: Investigating Documented Privacy Changes in Android OS
#     Distinguished: False
#   Paper Name: Your Code Secret Belongs to Me: Neural Code Completion Tools Can Memorize Hard-coded Credentials
#     Distinguished: False
#   Paper Name: PPM: Automated Generation of Diverse Programming Problems for Benchmarking Code Generation Models
#     Distinguished: False
#   Paper Name: Demystifying Invariant Effectiveness for Securing Smart Contracts
#     Distinguished: False
#   Paper Name: Static Application Security Testing (SAST) Tools for Smart Contracts: How Far Are We?
#     Distinguished: True
#   Paper Name: On the Contents and Utility of IoT Cybersecurity Guidelines
#     Distinguished: False
#   Paper Name: Keeping Secrets: Multi-objective Genetic Improvement for Detecting and Reducing Information Leakage
#     Distinguished: False
#   Paper Name: ThirdEye: Attention Maps for Safe Autonomous Driving Systems
#     Distinguished: False
#   Paper Name: Scrutinizing Privacy Policy Compliance of Virtual Personal Assistant Apps
#     Distinguished: False
#   Paper Name: An Empirical Study of Automation in Software Security Patch Management
#     Distinguished: False
#   Paper Name: Are They Toeing the Line? Diagnosing Privacy Compliance Violations among Browser Extensions
#     Distinguished: False
#   Paper Name: A Needle is an Outlier in a Haystack: Hunting Malicious PyPI Packages with Code Clustering
#     Distinguished: False
#   Paper Name: Merge-Replay: Efficient IFDS-Based Taint Analysis by Consolidating Equivalent Value Flows
#     Distinguished: True
#   Paper Name: Learning to Locate and Describe Vulnerabilities
#     Distinguished: False
#   Paper Name: When Less is Enough: Positive and Unlabeled Learning Model for Vulnerability Detection
#     Distinguished: False
#   Paper Name: SCPatcher: Mining Crowd Security Discussions to Enrich Secure Coding Practices
#     Distinguished: False
#   Paper Name: DeFiWarder: Protecting DeFi Apps from Token Leaking Vulnerabilities
#     Distinguished: False
#   Paper Name: VD-Guard: DMA Guided Fuzzing for Hypervisor Virtual Device
#     Distinguished: False
#   Paper Name: Chronos: Time-Aware Zero-Shot Identification of Libraries from Vulnerability Reports
#     Distinguished: False
#   Paper Name: Understanding the Threats of Upstream Vulnerabilities to Downstream Projects in the Maven Ecosystem
#     Distinguished: False
#   Paper Name: SecBench.js: An Executable Security Benchmark Suite for Server-Side JavaScript
#     Distinguished: False
#   Paper Name: On Privacy Weaknesses and Vulnerabilities in Software Systems
#     Distinguished: False
#   Paper Name: An Empirical Study of Deep Learning Models for Vulnerability Detection
#     Distinguished: False
#   Paper Name: DeepVD: Toward Class-Separation Features for Neural Network Vulnerability Detection
#     Distinguished: False
#   Paper Name: Enhancing Deep Learning-based Vulnerability Detection by Building Behavior Graph Model
#     Distinguished: False
#   Paper Name: Vulnerability Detection with Graph Simplification and Enhanced Graph Representation Learning
#     Distinguished: False
#   Paper Name: Does data sampling improve deep learning-based vulnerability detection? Yeas! and Nays!
#     Distinguished: False
#   Paper Name: Silent Vulnerable Dependency Alert Prediction with Vulnerability Key Aspect Explanation
#     Distinguished: False
#   Paper Name: Compatible Remediation on Vulnerabilities from Third-Party Libraries for Java Projects
#     Distinguished: True
#   Paper Name: Automated Black-box Testing of Mass Assignment Vulnerabilities in RESTful APIs
#     Distinguished: False
#   Paper Name: CoLeFunDa: Explainable Silent Vulnerability Fix Identification
#     Distinguished: False
#   Paper Name: REDriver: Runtime Enforcement for Autonomous Vehicles
#     Distinguished: False
#   Paper Name: Scalable Relational Analysis via Relational Bound Propagation
#     Distinguished: False
#   Paper Name: Kind Controllers and Fast Heuristics for Non-Well-Separated GR(1) Specifications
#     Distinguished: False
#   Paper Name: Enabling Runtime Verification of Causal Discovery Algorithms with Automated Conditional Independence Reasoning
#     Distinguished: False
#   Paper Name: Translation Validation for JIT Compiler in the V8 JavaScript Engine
#     Distinguished: False
#   Paper Name: It's Not a Feature, It's a Bug: Fault-Tolerant Model Mining from Noisy Data
#     Distinguished: False
#   Paper Name: Verifying Declarative Smart Contracts
#     Distinguished: False
#   Paper Name: GPTScan: Detecting Logic Vulnerabilities in Smart Contracts by Combining GPT with Program Analysis
#     Distinguished: False
#   Paper Name: PrettySmart: Detecting Permission Re-delegation Vulnerability for Token Behaviors in Smart Contracts
#     Distinguished: False
#   Paper Name: Combining Structured Static Code Information and Dynamic Symbolic Traces for Software Vulnerability Prediction
#     Distinguished: False
#   Paper Name: SCVHunter: Smart Contract Vulnerability Detection Based on Heterogeneous Graph Attention Network
#     Distinguished: False
#   Paper Name: PS3: Precise Patch Presence Test based on Semantic Symbolic Signature
#     Distinguished: False
#   Paper Name: Safeguarding DeFi Smart Contracts against Oracle Deviations
#     Distinguished: True
#   Paper Name: Data Leakage in Notebooks: Static Detection and Better Processes
#     Distinguished: False
#   Paper Name: GLITCH: Automated Polyglot Security Smell Detection in Infrastructure as Code
#     Distinguished: False
#   Paper Name: Precise (Un)Affected Version Analysis for Web Vulnerabilities
#     Distinguished: False
#   Paper Name: Leveraging Practitioners' Feedback to Improve a Security Linter
#     Distinguished: False
#   Paper Name: Insight: Exploring Cross-Ecosystem Vulnerability Impacts
#     Distinguished: False

# %% [markdown]
# # Sampling of the Papers

# %% [markdown]
# ## Sample 6 papers per domain (3 distinguished and 3 not distinguished)

# %%
def sample_papers(merged_dict_all):
    """
    Randomly samples up to 6 papers per domain from the given dataset.

    Args:
        merged_dict_all (dict): A dictionary where each domain maps to a dictionary containing a list of papers.

    Returns:
        dict: A dictionary with the same domain keys, where each domain maps to a list of up to 6 sampled papers 
              (3 distinguished and 3 non-distinguished, if available).
    """
    sampled_papers = {}

    # Iterate over each domain in merged_dict_all
    for domain, domain_data in merged_dict_all.items():
        # Separate papers into distinguished and non-distinguished lists
        distinguished_papers = [paper for paper in domain_data['papers'] if paper['distinguished']]
        non_distinguished_papers = [paper for paper in domain_data['papers'] if not paper['distinguished']]

        # Sample 3 distinguished papers and 3 non-distinguished papers (if possible)
        sampled_distinguished = random.sample(distinguished_papers, min(3, len(distinguished_papers)))
        sampled_non_distinguished = random.sample(non_distinguished_papers, min(3, len(non_distinguished_papers)))

        # Combine the sampled papers
        sampled_papers[domain] = sampled_distinguished + sampled_non_distinguished

    return sampled_papers

# %%
def write_sampled_papers_to_csv(sampled_papers, filename='sampled_papers.csv'):
    """
    Writes sampled papers data to a CSV file.

    Args:
        sampled_papers (dict): A dictionary where each key is a domain, and the value is a list of sampled paper dictionaries.
        filename (str, optional): The name of the CSV file to write to. Defaults to 'sampled_papers.csv'.

    Behavior:
        - Writes a header row to the CSV file.
        - Iterates through the sampled papers and writes each paper's details (domain, name, authors, distinguished status, and URL) as a row.
    """
    os.makedirs('csv_files', exist_ok=True)
    filepath = os.path.join('csv_files', filename)

    # Define the header for the CSV
    header = ['Domain', 'Paper Name', 'Authors', 'Distinguished', 'URL']

    # Open the CSV file in write mode
    with open(filepath, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(header)

        # Iterate over the sampled papers and write each one to the CSV
        for domain, papers in sampled_papers.items():
            for paper in papers:
                writer.writerow([domain, paper['name'], paper['authors'], paper['distinguished'], paper['url']])

# %%
sampled_papers = sample_papers(merged_dict_all)
for domain, papers in sampled_papers.items():
    print(f"Domain: {domain}")
    for paper in papers:
        print(f"  Paper Name: {paper['name']}")
        #print(f"    Authors: {paper['authors']}")
        print(f"    Distinguished: {paper['distinguished']}")
        #print(f"    URL: {paper['url']}")
    print("\n")
# Out:
# Domain: domain_ai_se
#   Paper Name: Benchmarking Robustness of AI-enabled Multi-sensor Fusion Systems: Challenges and Opportunities
#     Distinguished: True
#   Paper Name: Can Machine Learning Pipelines Be Better Configured?
#     Distinguished: True
#   Paper Name: CARGO: AI-Guided Dependency Analysis for Migrating Monolithic Applications to Microservices Architecture
#     Distinguished: True
#   Paper Name: Uncovering the Causes of Emotions in Software Developer Communication Using Zero-shot LLMs
#     Distinguished: False
#   Paper Name: Natural Is The Best: Model-Agnostic Code Simplification for Pre-trained Large Language Models
#     Distinguished: False
#   Paper Name: Patching Weak Convolutional Neural Network Models through Modularization and Composition
#     Distinguished: False
#
#
# Domain: domain_testing_analysis
#   Paper Name: Mutation-based Fault Localization of Deep Neural Networks
#     Distinguished: True
#   Paper Name: PHYFU: Fuzzing Modern Physics Simulation Engines
#     Distinguished: True
#   Paper Name: QATest: A Uniform Fuzzing Framework for Question Answering Systems
#     Distinguished: True
#   Paper Name: Detecting Logic Bugs in Graph Database Management Systems via Injective and Surjective Graph Pattern Transformation
#     Distinguished: False
#   Paper Name: FuzzInMem: Fuzzing Programs via In-memory Structures
#     Distinguished: False
#   Paper Name: NaturalFuzz: Natural Input Generation for Big Data Analytics
#     Distinguished: False
#
#
# Domain: domain_analytics
#   Paper Name: Code Search is All You Need? Improving Code Suggestions with Code Search
#     Distinguished: True
#   Paper Name: TraStrainer: Adaptive Sampling for Distributed Traces with System Runtime State
#     Distinguished: True
#   Paper Name: Domain Adaptive Code Completion via Language Models and Decoupled Domain Databases
#     Distinguished: True
#   Paper Name: Learning to Synthesize Relational Invariants
#     Distinguished: False
#   Paper Name: Learning Graph-based Code Representations for Source-level Functional Similarity Detection
#     Distinguished: False
#   Paper Name: From Misuse to Mastery: Enhancing Code Generation with Knowledge-Driven AI Chaining
#     Distinguished: False
#
#
# Domain: domain_evolution
#   Paper Name: Understanding Developers' Discussions and Perceptions on Non-Functional Requirements: The Case of the Spring Ecosystem
#     Distinguished: True
#   Paper Name: HyperAST: Enabling Efficient Analysis of Software Histories at Scale
#     Distinguished: True
#   Paper Name: Hard to Read and Understand Pythonic Idioms? DeIdiom and Explain Them in Non-Idiomatic Equivalent Code
#     Distinguished: True
#   Paper Name: Evaluating Code Summarization Techniques: A New Metric and an Empirical Characterization
#     Distinguished: False
#   Paper Name: Fine-grained, accurate and scalable source differencing
#     Distinguished: False
#   Paper Name: Where to Go Now? Finding Alternatives for Declining Packages in the npm Ecosystem
#     Distinguished: False
#
#
# Domain: domain_requirements_modelling
#   Paper Name: A Qualitative Study on the Implementation Design Decisions of Developers
#     Distinguished: True
#   Paper Name: Detecting Smart Home Automation Application Interferences with Domain Knowledge
#     Distinguished: True
#   Paper Name: Compiler Testing using Template Java Programs
#     Distinguished: True
#   Paper Name: Unsupervised Summarization of Privacy Concerns in Mobile Application Reviews
#     Distinguished: False
#   Paper Name: Automatically Detecting Visual Bugs in HTML5 <canvas> Games
#     Distinguished: False
#   Paper Name: An Energy-Aware Approach to Design Self-Adaptive AI-based Applications on the Edge
#     Distinguished: False
#
#
# Domain: domain_human_social
#   Paper Name: A Longitudinal Study of Student Contributions to OSS vs. OSS4SG with a Lightweight Intervention
#     Distinguished: True
#   Paper Name: Do I Belong? Modeling Sense of Virtual Community Among Linux Kernel Contributors
#     Distinguished: True
#   Paper Name: Causal Relationships and Programming Outcomes: A Transcranial Magnetic Stimulation Experiment
#     Distinguished: True
#   Paper Name: [Remote] Understanding the topics and challenges of GPU programming by classifying and analyzing Stack Overflow posts
#     Distinguished: False
#   Paper Name: An Analysis of the Costs and Benefits of Autocomplete in IDEs
#     Distinguished: False
#   Paper Name: Unveiling the Life Cycle of User Feedback: Best Practices from Software Practitioners
#     Distinguished: False
#
#
# Domain: domain_dependability_security
#   Paper Name: Static Application Security Testing (SAST) Tools for Smart Contracts: How Far Are We?
#     Distinguished: True
#   Paper Name: Mate! Are You Really Aware? An Explainability-Guided Testing Framework for Robustness of Malware Detectors
#     Distinguished: True
#   Paper Name: [Remote] TransRacer: Function Dependence-Guided Transaction Race Detection for Smart Contracts
#     Distinguished: True
#   Paper Name: An Empirical Study of Automation in Software Security Patch Management
#     Distinguished: False
#   Paper Name: REDriver: Runtime Enforcement for Autonomous Vehicles
#     Distinguished: False
#   Paper Name: Precise (Un)Affected Version Analysis for Web Vulnerabilities
#     Distinguished: False

# %%
write_sampled_papers_to_csv(sampled_papers, 'sampled_papers.csv')
